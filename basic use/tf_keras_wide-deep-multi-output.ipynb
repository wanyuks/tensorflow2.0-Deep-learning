# %%
import matplotlib as mlt
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd

import sys
import os
import time

import tensorflow as tf
from tensorflow import keras

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# %% [markdown]
# 读取所用的数据

# %%
housing = fetch_california_housing()
x_train_all, x_test, y_train_all, y_test = train_test_split(housing.data,
                                                           housing.target,
                                                           test_size=0.25,
                                                           random_state=7)
x_train, x_val, y_train, y_val = train_test_split(x_train_all,
                                                  y_train_all,
                                                  test_size=0.25,
                                                  random_state=7)
print("train shape: ", x_train.shape)
print("validation shape: ", x_val.shape)
print("test shape: ", x_test.shape)
# Out:
# train shape:  (11610, 8)
# validation shape:  (3870, 8)
# test shape:  (5160, 8)

# %% [markdown]
# 使用函数式API实现wide and deep模型

# %% [markdown]
# 做归一化

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_val_scaled = scaler.transform(x_val)
x_test_scaled = scaler.transform(x_test)

# %% [markdown]
# 构建模型

# %%
# 实现多输出
input_wide = keras.layers.Input(shape=[5])
input_deep = keras.layers.Input(shape=[6])
hidden1 = keras.layers.Dense(30, activation="relu")(input_deep)
hidden2 = keras.layers.Dense(30, activation="relu")(hidden1)
concat = keras.layers.concatenate([input_wide, hidden2])
output = keras.layers.Dense(1)(concat)
output2 = keras.layers.Dense(1)(hidden2)
model = keras.models.Model(inputs=[input_wide, input_deep], outputs=[output, output2])

# %%
model.layers
# Out:
# [<tensorflow.python.keras.layers.core.Dense at 0x1da4f66c630>,
#  <tensorflow.python.keras.layers.core.Dense at 0x1da4f66c320>,
#  <tensorflow.python.keras.layers.core.Dense at 0x1da4f214d68>]

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 300)               235500
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               30100
# _________________________________________________________________
# dense_8 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 266,610
# Trainable params: 266,610
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='sgd',loss='mean_squared_error')

# %% [markdown]
# 开始训练模型

# %%
x_train_scaled_wide = x_train_scaled[:, :5]
x_train_scaled_deep = x_train_scaled[:, 2:]
x_val_scaled_wide = x_val_scaled[:,:5]
x_val_scaled_deep = x_val_scaled[:, 2:]
x_test_scaled_wide = x_test_scaled[:, :5]
x_test_scaled_deep = x_test_scaled[:, 2:]
history = model.fit([x_train_scaled_wide, x_train_scaled_deep],
                    [y_train, y_train],
                    epochs=10,
                    validation_data=(
                        [x_val_scaled_wide, x_val_scaled_deep],
                        [y_val, y_val]))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/10
# 11610/11610 [==============================] - 1s 85us/sample - loss: 2.2850 - dense_2_loss: 0.8835 - dense_3_loss: 1.4008 - val_loss: 1.3032 - val_dense_2_loss: 0.4966 - val_dense_3_loss: 0.8065
# Epoch 2/10
# 11610/11610 [==============================] - 0s 43us/sample - loss: 1.1047 - dense_2_loss: 0.4521 - dense_3_loss: 0.6524 - val_loss: 1.0461 - val_dense_2_loss: 0.4385 - val_dense_3_loss: 0.6077
# Epoch 3/10
# 11610/11610 [==============================] - 0s 39us/sample - loss: 0.9834 - dense_2_loss: 0.4197 - dense_3_loss: 0.5637 - val_loss: 1.0120 - val_dense_2_loss: 0.4248 - val_dense_3_loss: 0.5873
# Epoch 4/10
# 11610/11610 [==============================] - 1s 46us/sample - loss: 0.9618 - dense_2_loss: 0.4341 - dense_3_loss: 0.5278 - val_loss: 0.9605 - val_dense_2_loss: 0.4176 - val_dense_3_loss: 0.5429
# Epoch 5/10
# 11610/11610 [==============================] - 1s 51us/sample - loss: 0.9220 - dense_2_loss: 0.4059 - dense_3_loss: 0.5160 - val_loss: 0.9180 - val_dense_2_loss: 0.4007 - val_dense_3_loss: 0.5173
# Epoch 6/10
# 11610/11610 [==============================] - 1s 44us/sample - loss: 0.8636 - dense_2_loss: 0.3804 - dense_3_loss: 0.4831 - val_loss: 0.8964 - val_dense_2_loss: 0.3911 - val_dense_3_loss: 0.5053
# Epoch 7/10
# 11610/11610 [==============================] - 1s 45us/sample - loss: 0.8431 - dense_2_loss: 0.3748 - dense_3_loss: 0.4682 - val_loss: 0.8833 - val_dense_2_loss: 0.3875 - val_dense_3_loss: 0.4958
# Epoch 8/10
# 11610/11610 [==============================] - 1s 51us/sample - loss: 0.8235 - dense_2_loss: 0.3681 - dense_3_loss: 0.4552 - val_loss: 0.8610 - val_dense_2_loss: 0.3838 - val_dense_3_loss: 0.4773
# Epoch 9/10
# 11610/11610 [==============================] - 0s 41us/sample - loss: 0.8050 - dense_2_loss: 0.3631 - dense_3_loss: 0.4424 - val_loss: 0.8314 - val_dense_2_loss: 0.3720 - val_dense_3_loss: 0.4594
# Epoch 10/10
# 11610/11610 [==============================] - 0s 42us/sample - loss: 0.7915 - dense_2_loss: 0.3577 - dense_3_loss: 0.4335 - val_loss: 0.8334 - val_dense_2_loss: 0.3738 - val_dense_3_loss: 0.4597

# %% [markdown]
# 查看history

# %%
print("history type:",type(history))
print(history.history)
# Out:
# history type: <class 'tensorflow.python.keras.callbacks.History'>
# {'loss': [2.2414572177800265, 0.5366708481398496, 0.4642846742283214, 0.44211164492260324, 0.4102861109451814, 0.38839729609706186, 0.37477654895999213, 0.3618625250968066, 0.36169644176093013, 0.3453662946300073], 'accuracy': [0.7630182, 0.8206364, 0.83583635, 0.8428182, 0.85194546, 0.8600364, 0.8668727, 0.86932725, 0.87136364, 0.8774545], 'val_loss': [0.5362856708526611, 0.5579980314493179, 0.4026535280585289, 0.39917497502565386, 0.4062749324798584, 0.37778860169649126, 0.37311150260567666, 0.376443230676651, 0.3728054626822472, 0.38163680585026744], 'val_accuracy': [0.8336, 0.7996, 0.8626, 0.8548, 0.857, 0.8648, 0.8732, 0.874, 0.8744, 0.8716]}

# %% [markdown]
# 画出各指标的变化趋势

# %%
def curves(history):
    pd.DataFrame(history.history).plot(figsize=(10, 6))
    plt.grid(True)
    plt.gca().set_ylim(0.1)
    plt.show()
curves(history)

# %%
model.evaluate([x_test_scaled_wide, x_test_scaled_deep], [y_test,y_test])
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# [0.7932806680368822, 0.36567557, 0.42931253]
